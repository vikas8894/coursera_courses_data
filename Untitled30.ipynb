# %% [markdown]
# <a href="https://colab.research.google.com/github/vikas8894/coursera_courses_data/blob/main/Untitled30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import time

# %%
df=pd.read_csv('/content/coursera_courses.csv')
df
# Out:
#      Unnamed: 0                                       course_title  \
# 0           196  (ISC)² Systems Security Certified Practitioner...
# 1           648                           .NET FullStack Developer
# 2           928  21st Century Energy Transition: how do we make...
# 3           580  A Crash Course in Causality:  Inferring Causal...
# 4           918                                   A life with ADHD
# ..          ...                                                ...
# 995         412  Étudier en France: French Intermediate course ...
# 996         571  Цифровий маркетинг і електронна комерція від G...
# 997         863                          إدارة المشروعات من Google
# 998         820                         تحليلات البيانات من Google
# 999         887  用 Python 做商管程式設計（一）(Programming for Business C...
#
#             course_organization   course_certificate_type   course_time  \
# 0                          ISC2            Specialization  3 - 6 Months
# 1               Board Infinity             Specialization  1 - 3 Months
# 2         University of Alberta                    Course  1 - 3 Months
# 3    University of Pennsylvania                    Course  1 - 3 Months
# 4          University of Geneva                    Course  1 - 3 Months
# ..                          ...                       ...           ...
# 995         École Polytechnique                    Course  1 - 3 Months
# 996                      Google  Professional Certificate  3 - 6 Months
# 997                      Google  Professional Certificate  3 - 6 Months
# 998                      Google  Professional Certificate  3 - 6 Months
# 999  National Taiwan University                    Course  1 - 3 Months
#
#      course_rating course_reviews_num course_difficulty  \
# 0              4.7                484          Beginner
# 1              4.3                 49      Intermediate
# 2              4.8                 59          Beginner
# 3              4.7                515      Intermediate
# 4              NaN                NaN          Beginner
# ..             ...                ...               ...
# 995            4.8               4.6k      Intermediate
# 996            4.9               1.2k          Beginner
# 997            4.8                256          Beginner
# 998            4.8                154          Beginner
# 999            4.9                809          Beginner
#
#                                             course_url  \
# 0    https://www.coursera.org/specializations/sscp-...
# 1    https://www.coursera.org/specializations/dot-n...
# 2    https://www.coursera.org/learn/21st-century-en...
# 3    https://www.coursera.org/learn/crash-course-in...
# 4        https://www.coursera.org/learn/life-with-adhd
# ..                                                 ...
# 995   https://www.coursera.org/learn/etudier-en-france
# 996  https://www.coursera.org/professional-certific...
# 997  https://www.coursera.org/professional-certific...
# 998  https://www.coursera.org/professional-certific...
# 999                https://www.coursera.org/learn/pbc1
#
#     course_students_enrolled  \
# 0                      6,706
# 1                      2,140
# 2                      4,282
# 3                     38,833
# 4                        NaN
# ..                       ...
# 995                  516,758
# 996                    7,584
# 997                    2,716
# 998                    2,624
# 999                   38,453
#
#                                          course_skills  \
# 0    ['Security Software', 'Risk Management', 'Acce...
# 1    ['Web API', 'Web Development', 'Cascading Styl...
# 2                                                   []
# 3                                                   []
# 4    ['differential diagnosis and comorbidities', '...
# ..                                                 ...
# 995                                                 []
# 996  ['Marketing', 'Social Media', 'Strategy', 'Dat...
# 997  ['Leadership and Management', 'Project Managem...
# 998  ['دول البيانات', 'مؤثرات عرض البيانات (DataViz...
# 999                                                 []
#
#                                         course_summary  \
# 0                                                   []
# 1    ['Master .NET full stack web dev: from .NET co...
# 2    ['Understand the complexity of systems supplyi...
# 3                                                   []
# 4    [' Understand what ADHD is and the challenges ...
# ..                                                 ...
# 995                                                 []
# 996  ['Ви вивчите основи цифрового маркетингу та ел...
# 997  ['اكتساب فهم كبير للممارسات والمهارات اللازمة ...
# 998  ['اكتساب فهم شامل للممارسات والعمليات التي يست...
# 999                                                 []
#
#                                     course_description
# 0    Pursue better IT security job opportunities an...
# 1    Develop the proficiency required to design and...
# 2    Affordable, abundant and reliable energy is fu...
# 3    We have all heard the phrase “correlation does...
# 4    What is ADHD and what are the challenges that ...
# ..                                                 ...
# 995  Ce cours de français de niveau intermédiaire B...
# 996  За менш ніж шість місяців, без досвіду або спе...
# 997  استعد لمهنة جديدة في مجال إدارة المشروعات عالي...
# 998  استعد لمهنة جديدة في مجال تحليلات البيانات عال...
# 999  本系列課程從零開始，教授一般認為最適合初學者的程式語言「Python」，目標是讓大家在完成本...
#
# [1000 rows x 13 columns]

# %%
df.drop_duplicates()

# %%
df.info()

# %%
df.describe(include='object')
# Out:
#                               course_title course_organization  \
# count                                 1000                1000
# unique                                 992                 156
# top     Introduction to Project Management              Google
# freq                                     2                  97
#
#        course_certificate_type   course_time course_reviews_num  \
# count                     1000          1000                994
# unique                       4             4                530
# top                     Course  3 - 6 Months               1.3k
# freq                       496           456                 15
#
#        course_difficulty                                         course_url  \
# count               1000                                               1000
# unique                 4                                               1000
# top             Beginner  https://www.coursera.org/specializations/sscp-...
# freq                 679                                                  1
#
#        course_students_enrolled course_skills course_summary  \
# count                       964          1000           1000
# unique                      960           639            579
# top                      20,831            []             []
# freq                          2           355            420
#
#                                        course_description
# count                                                 999
# unique                                                999
# top     Pursue better IT security job opportunities an...
# freq                                                    1

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# course_title                 0
# course_organization          0
# course_certificate_type      0
# course_time                  0
# course_rating                6
# course_reviews_num           6
# course_difficulty            0
# course_url                   0
# course_students_enrolled    36
# course_skills                0
# course_summary               0
# course_description           1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 962 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                962 non-null    int64
#  1   course_title              962 non-null    object
#  2   course_organization       962 non-null    object
#  3   course_certificate_type   962 non-null    object
#  4   course_time               962 non-null    object
#  5   course_rating             962 non-null    float64
#  6   course_reviews_num        962 non-null    object
#  7   course_difficulty         962 non-null    object
#  8   course_url                962 non-null    object
#  9   course_students_enrolled  962 non-null    object
#  10  course_skills             962 non-null    object
#  11  course_summary            962 non-null    object
#  12  course_description        962 non-null    object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 105.2+ KB

# %%
for i in df.describe(include='object'):
  print(i)
  print(df[i].unique())
  print('-'*75)

# %%
df['course_students_enrolled']=df['course_students_enrolled'].str.replace(',','').astype(int)
df
# Out:
#      Unnamed: 0                                       course_title  \
# 0           196  (ISC)² Systems Security Certified Practitioner...
# 1           648                           .NET FullStack Developer
# 2           928  21st Century Energy Transition: how do we make...
# 3           580  A Crash Course in Causality:  Inferring Causal...
# 5           433                                           AI & Law
# ..          ...                                                ...
# 995         412  Étudier en France: French Intermediate course ...
# 996         571  Цифровий маркетинг і електронна комерція від G...
# 997         863                          إدارة المشروعات من Google
# 998         820                         تحليلات البيانات من Google
# 999         887  用 Python 做商管程式設計（一）(Programming for Business C...
#
#             course_organization   course_certificate_type   course_time  \
# 0                          ISC2            Specialization  3 - 6 Months
# 1               Board Infinity             Specialization  1 - 3 Months
# 2         University of Alberta                    Course  1 - 3 Months
# 3    University of Pennsylvania                    Course  1 - 3 Months
# 5               Lund University                    Course   1 - 4 Weeks
# ..                          ...                       ...           ...
# 995         École Polytechnique                    Course  1 - 3 Months
# 996                      Google  Professional Certificate  3 - 6 Months
# 997                      Google  Professional Certificate  3 - 6 Months
# 998                      Google  Professional Certificate  3 - 6 Months
# 999  National Taiwan University                    Course  1 - 3 Months
#
#      course_rating course_reviews_num course_difficulty  \
# 0              4.7                484          Beginner
# 1              4.3                 49      Intermediate
# 2              4.8                 59          Beginner
# 3              4.7                515      Intermediate
# 5              4.7                361          Beginner
# ..             ...                ...               ...
# 995            4.8               4.6k      Intermediate
# 996            4.9               1.2k          Beginner
# 997            4.8                256          Beginner
# 998            4.8                154          Beginner
# 999            4.9                809          Beginner
#
#                                             course_url  \
# 0    https://www.coursera.org/specializations/sscp-...
# 1    https://www.coursera.org/specializations/dot-n...
# 2    https://www.coursera.org/learn/21st-century-en...
# 3    https://www.coursera.org/learn/crash-course-in...
# 5                https://www.coursera.org/learn/ai-law
# ..                                                 ...
# 995   https://www.coursera.org/learn/etudier-en-france
# 996  https://www.coursera.org/professional-certific...
# 997  https://www.coursera.org/professional-certific...
# 998  https://www.coursera.org/professional-certific...
# 999                https://www.coursera.org/learn/pbc1
#
#      course_students_enrolled  \
# 0                        6706
# 1                        2140
# 2                        4282
# 3                       38833
# 5                       25442
# ..                        ...
# 995                    516758
# 996                      7584
# 997                      2716
# 998                      2624
# 999                     38453
#
#                                          course_skills  \
# 0    ['Security Software', 'Risk Management', 'Acce...
# 1    ['Web API', 'Web Development', 'Cascading Styl...
# 2                                                   []
# 3                                                   []
# 5                                                   []
# ..                                                 ...
# 995                                                 []
# 996  ['Marketing', 'Social Media', 'Strategy', 'Dat...
# 997  ['Leadership and Management', 'Project Managem...
# 998  ['دول البيانات', 'مؤثرات عرض البيانات (DataViz...
# 999                                                 []
#
#                                         course_summary  \
# 0                                                   []
# 1    ['Master .NET full stack web dev: from .NET co...
# 2    ['Understand the complexity of systems supplyi...
# 3                                                   []
# 5    ['Understand the legal significance of the art...
# ..                                                 ...
# 995                                                 []
# 996  ['Ви вивчите основи цифрового маркетингу та ел...
# 997  ['اكتساب فهم كبير للممارسات والمهارات اللازمة ...
# 998  ['اكتساب فهم شامل للممارسات والعمليات التي يست...
# 999                                                 []
#
#                                     course_description
# 0    Pursue better IT security job opportunities an...
# 1    Develop the proficiency required to design and...
# 2    Affordable, abundant and reliable energy is fu...
# 3    We have all heard the phrase “correlation does...
# 5    About this Course\nThis four-week course title...
# ..                                                 ...
# 995  Ce cours de français de niveau intermédiaire B...
# 996  За менш ніж шість місяців, без досвіду або спе...
# 997  استعد لمهنة جديدة في مجال إدارة المشروعات عالي...
# 998  استعد لمهنة جديدة في مجال تحليلات البيانات عال...
# 999  本系列課程從零開始，教授一般認為最適合初學者的程式語言「Python」，目標是讓大家在完成本...
#
# [962 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 962 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                962 non-null    int64
#  1   course_title              962 non-null    object
#  2   course_organization       962 non-null    object
#  3   course_certificate_type   962 non-null    object
#  4   course_time               962 non-null    object
#  5   course_rating             962 non-null    float64
#  6   course_reviews_num        962 non-null    object
#  7   course_difficulty         962 non-null    object
#  8   course_url                962 non-null    object
#  9   course_students_enrolled  962 non-null    int64
#  10  course_skills             962 non-null    object
#  11  course_summary            962 non-null    object
#  12  course_description        962 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 105.2+ KB

# %%
df.head(10)
# Out:
#     Unnamed: 0                                       course_title  \
# 0          196  (ISC)² Systems Security Certified Practitioner...
# 1          648                           .NET FullStack Developer
# 2          928  21st Century Energy Transition: how do we make...
# 3          580  A Crash Course in Causality:  Inferring Causal...
# 5          433                                           AI & Law
# 6          591           AI Applications in Marketing and Finance
# 7          792               AI Applications in People Management
# 8           72                                    AI For Business
# 9           47                                    AI For Everyone
# 10         537               AI For Everyone （すべての人のためのAIリテラシー講座）
#
#            course_organization course_certificate_type   course_time  \
# 0                         ISC2          Specialization  3 - 6 Months
# 1              Board Infinity           Specialization  1 - 3 Months
# 2        University of Alberta                  Course  1 - 3 Months
# 3   University of Pennsylvania                  Course  1 - 3 Months
# 5              Lund University                  Course   1 - 4 Weeks
# 6   University of Pennsylvania                  Course   1 - 4 Weeks
# 7   University of Pennsylvania                  Course   1 - 4 Weeks
# 8   University of Pennsylvania          Specialization  3 - 6 Months
# 9              DeepLearning.AI                  Course   1 - 4 Weeks
# 10             DeepLearning.AI                  Course  1 - 3 Months
#
#     course_rating course_reviews_num course_difficulty  \
# 0             4.7                484          Beginner
# 1             4.3                 49      Intermediate
# 2             4.8                 59          Beginner
# 3             4.7                515      Intermediate
# 5             4.7                361          Beginner
# 6             4.7                130             Mixed
# 7             4.7                 67             Mixed
# 8             4.7                364          Beginner
# 9             4.8              39.2k          Beginner
# 10            4.8                244          Beginner
#
#                                            course_url  \
# 0   https://www.coursera.org/specializations/sscp-...
# 1   https://www.coursera.org/specializations/dot-n...
# 2   https://www.coursera.org/learn/21st-century-en...
# 3   https://www.coursera.org/learn/crash-course-in...
# 5               https://www.coursera.org/learn/ai-law
# 6   https://www.coursera.org/learn/wharton-ai-appl...
# 7   https://www.coursera.org/learn/wharton-ai-appl...
# 8   https://www.coursera.org/specializations/ai-fo...
# 9      https://www.coursera.org/learn/ai-for-everyone
# 10  https://www.coursera.org/learn/ai-for-everyone-ja
#
#     course_students_enrolled  \
# 0                       6706
# 1                       2140
# 2                       4282
# 3                      38833
# 5                      25442
# 6                       7307
# 7                       5066
# 8                      13092
# 9                    1080159
# 10                     27542
#
#                                         course_skills  \
# 0   ['Security Software', 'Risk Management', 'Acce...
# 1   ['Web API', 'Web Development', 'Cascading Styl...
# 2                                                  []
# 3                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8   ['Machine Learning', 'Machine Learning Algorit...
# 9                                                  []
# 10                                                 []
#
#                                        course_summary  \
# 0                                                  []
# 1   ['Master .NET full stack web dev: from .NET co...
# 2   ['Understand the complexity of systems supplyi...
# 3                                                  []
# 5   ['Understand the legal significance of the art...
# 6                                                  []
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                                                 []
#
#                                    course_description
# 0   Pursue better IT security job opportunities an...
# 1   Develop the proficiency required to design and...
# 2   Affordable, abundant and reliable energy is fu...
# 3   We have all heard the phrase “correlation does...
# 5   About this Course\nThis four-week course title...
# 6   In this course, you will learn about AI-powere...
# 7   In this course, you will learn about Artificia...
# 8   This specialization will provide learners with...
# 9   AI is not only for engineers. If you want your...
# 10  AIはエンジニアだけのものではなく、今や社会⼈の基本リテラシーと⾔えます。本\nコースは、A...

# %% [markdown]
#  Distribution of course ratings in dataset

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df['course_rating'],kde=True,color='red')
plt.xlabel('customer ratings')
plt.ylabel('count')
plt.title('customer ratings distribution')
plt.show()

# %% [markdown]
# Reading= Most of the courses offered by coursera has customer rating from 4.6 to 4.9 out of 5 which tells the curses offered by coursera are worth to get enrolled for future studies.

# %% [markdown]
# How the courses are measured on difficulty level

# %%
sns.countplot(data=df, x="course_difficulty")
plt.xlabel("Difficulty Level")
plt.ylabel("Count")
plt.title("Distribution of Course Difficulty Levels")
plt.show()

# %% [markdown]
# Out of four categories maximum courses offered are meant for beginners level.

# %% [markdown]
# what duration course is most offered?

# %%
sns.countplot(data=df, x='course_time')
plt.xlabel("course_time")
plt.ylabel("Count")
plt.title("Distribution of Course as per time",fontdict={'color':'teal','size':20})
plt.show()

# %% [markdown]
# out from the courses offered maximum courses are between time duration of 3-6 months

# %%
sns.countplot(data=df, x='course_certificate_type',palette='Set2')
plt.xlabel("course_certificate_type")
plt.ylabel("Count")
plt.title("Distribution of Course as pertype",fontdict={'color':'green','size':20})
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(data=df,x='course_certificate_type', y='course_students_enrolled')
plt.xticks(rotation=9)
plt.xlabel('course certificate type')
plt.ylabel('number of students enrolled')
plt.show()

# %% [markdown]
# we can say the total of students that enroll themselves into total of three types viz., specialization, professional certificate and guided project is almost equal to number of students that enroll themselves into a course.

# %%
import spacy
from wordcloud import WordCloud

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.1)

# %%
import textblob

# %%
course_summary=df['course_summary']
key_phrases=' '.join(course_summary)

wordcloud = WordCloud(width=800, height=400, background_color="black", colormap="viridis").generate(key_phrases)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Top Key Phrases in Course Summaries")
plt.show()

# %%
course_skills = df["course_skills"]

# Here Combining all skills into a single string
all_skills_text = " ".join(course_skills)

wordcloud = WordCloud(width=800, height=400, background_color="white", colormap="cividis").generate(all_skills_text)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Most Frequently Mentioned Skills in Course Skills")
plt.show()

# %% [markdown]
# to find number of students enrolled into different type of courses

# %%
new_df=df.sort_values('course_students_enrolled',ascending=False)
new_df=new_df.head(10)
plt.barh(new_df['course_title'],new_df['course_students_enrolled'],color='lightgreen')
plt.ylabel('top 10 course title')
plt.xlabel('number of students enrolles')
plt.title('top 10 courses as per students enrolment')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# Maximum number of students get themselves enroll into the course which are for beginners and for time duration of 3-6 months where one course name is The Science Of Well Being with maximum enrollments.
